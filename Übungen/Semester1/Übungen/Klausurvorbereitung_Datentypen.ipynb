# %% [markdown]
# ## 1. Aufgabe aus der Klausur aus dem letzten Semester
#
# Schreiben Sie ein Python-Programm, das eine Liste von Produkten mit deren Preis pro Kilo und dem Gesamtpreis sortiert ausgibt. Das Programm soll eine Liste mit mindestens drei Produkten enthalten, wobei die Produkte als Tupel (Produktname, Preis pro Kilo, Gewicht in Kilo) strukturiert sind.
# Berechnen Sie den Gesamtpreis für jedes Produkt und sortieren Sie die Liste anhand des Gesamtpreises in aufsteigender Reihenfolge. Geben Sie die sortierten Produkte aus. Die Ausgabe Ihres Programms sollte beispielsweise so aussehen:

# %% [markdown]
# `1. Banane (Preis pro Kilo: 4.29€, Gewicht: 1.0kg, Gesamtpreis: 4.29€)`
#
# `2. Mango (Preis pro Kilo: 14.99€, Gewicht: 0.5kg, Gesamtpreis: 7.50€)`
#
# `3. Apfel (Preis pro Kilo: 4.95€, Gewicht: 5.0kg, Gesamtpreis: 24.75€)`

# %%
# hier einmal coden

# Hilfestellung; Liste der Produkte mit Preis pro Kilo und Gewicht
produkte = [("Banane", 4.29, 1.0), ("Apfel", 4.95, 5.0), ("Mango", 14.99, 0.5)]

# Gesamtpreis berechnen und in neuer Liste speichern

# Sortieren nach Gesamtpreis

# Ausgabe der sortierten Liste mit Gesamtpreisen

# %% [markdown]
# ## 2. Aufgabe WiSe 2024
#
# Schreiben Sie ein Python-Programm, das eine Aufgabenliste ausgibt. Das Programm soll bedingte Anweisungen und die Funktion enumerate() verwenden. Die Liste mit Aufgaben sollte mindestens drei Objekte beinhalten und als Tupel (Aufgabe, Priorität) strukturiert sein.
# Weisen Sie jeder Aufgabe eine Priorität in Form einer Ganzzahl zu und geben Sie diese Prioritäten zusammen mit den Aufgaben aus.
# Die Ausgabe Ihres Programms sollte beispielsweise so aussehen:

# %% [markdown]
# `Aufgabe 1: Einkaufen (Priorität: Hoch)`
#
# `Aufgabe 2: Hausaufgaben machen (Priorität: Mittel)`
#
# `Aufgabe 3: Sport treiben (Priorität: Niedrig)`

# %%
# hier einmal coden

# Aufgabenliste mit Prioritäten
aufgaben = 

# Ausgabe der Aufgabenliste MIT Prioritäten

# %% [markdown]
# ## 3. Aufgabe SoSe 2024
#
# Das Ziel dieser Aufgabe besteht darin, mithilfe einer for-Schleife die Kategorien von Datenobjekten in einem gegebenen Datenbestand zu analysieren.
#
# **Datenbestand:** Ein vordefinierter Datenbestand in Form eines Dictionaries ist gegeben. Jedes Daten-objekt im Dictionary ist einer bestimmten Kategorie zugeordnet, wie z.B., Obst, Gemüse oder Getränk. Implementierung: Die Lösung der Aufgabe soll alle Objekte im Datenbestand je Kategorien zählen und ausgeben.
#
# Die Ausgabe Ihres Programms sollte beispielsweise so aussehen:
#
# `Kategorie: Obst, Anzahl der Objekte: 4`
#
# `Kategorie: Gemüse, Anzahl der Objekte: 3`
#
# `Kategorie: Getränk, Anzahl der Objekte: 3`
#
# **Anmerkungen:** Verwenden Sie die items()-Methode des Dictionaries, um sowohl Schlüssel als auch Werte während der Iteration zu erhalten.

# %%
datenbestand = {
    "Apfel": "Obst",
    "Karotte": "Gemüse",
    "Wasser": "Getränk",
    "Banane": "Obst",
    "Tomate": "Gemüse",
    "Club Mate": "Spaßgetränk",
    "Orange": "Obst",
    "Brokkoli": "Gemüse",
    "Tee": "Getränk",
    "Traube": "Obst"
}

# %%
# hier einmal coden

# leeres dict für die Zählung der Kategorien erstellen
kategorie_zaehler = {}

# durch den Datenbestand iterieren und die Kategorien zählen

# Ausgabe der Kategorien und ihrer Häufigkeiten
